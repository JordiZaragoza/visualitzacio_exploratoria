# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# ### *Resume graficamente el data set DelayedFlights.csv*
# ### *Crea almenos una visualizacion para:*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("DelayedFlights.csv") # cargo el Data Frame
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %% [markdown]
# #### *Una variable categorica (UniqueCarrier)*

# %%
ax1 = sns.histplot(data=df, x="UniqueCarrier")

# %% [markdown]
# ### *Una variable numerica (ArrDelay)*

# %%
ax2 = sns.displot(data=df, x="ArrDelay")

# %% [markdown]
# ### *Una variable numerica y una categorica (ArrDelay y UniqueCarrier)*

# %%
ax3 = sns.barplot(data=df, x="UniqueCarrier", y="ArrDelay")

# %% [markdown]
# ### *Dos variables numericas (ArrDelay y DepDelay)*

# %%
ax4 = sns.regplot(data=df,x="ArrDelay", y="DepDelay", line_kws={"color":"r","alpha":0.5,"lw":5})

# %% [markdown]
# ### *Tres variables (ArrDelay, DepDelay y UniqueCarrier)*

# %%
ax5 = sns.FacetGrid(data=df, col="UniqueCarrier", hue="UniqueCarrier", col_wrap=4)
ax5.map(sns.scatterplot, "ArrDelay", "DepDelay")

# %% [markdown]
# ### *Mas de tres variables (ArrDelay, DepDelay, AirTime i UniqueCarrier)*

# %%
fig = plt.figure(figsize=(15,9))
ax6 = fig.add_subplot(111, projection='3d')
for s in df.UniqueCarrier.unique():
    ax6.scatter(df.AirTime[df.UniqueCarrier==s],
                df.DepDelay[df.UniqueCarrier==s],
                df.ArrDelay[df.UniqueCarrier==s],
                label=s)
plt.legend(loc='upper left')

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# ### *Exporta los graficos como imagenes o como html*

# %%
ax1.get_figure().savefig("1. UniqueCarrier.png")
ax2.savefig("2. ArrDelay.png")
ax3.get_figure().savefig("3. ArrDelay_UniqueCarrier.png")
ax4.get_figure().savefig("4. ArrDelay_DepDelay.png")
ax5.savefig("5. ArrDelay_DepDelay_UniqueCarrier.png")
ax6.get_figure().savefig("6. ArrDelay_DepDelay_AirTime_UniqueCarrier.png")

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# ### *Integra las visualizaciones graficas, en la tarea 5, del Sprint 3*

# %% [markdown]
# #### *Columnas a usar*

# %%
df = df[["Year","Month","DayofMonth","DepTime","CRSDepTime","ArrTime","CRSArrTime","UniqueCarrier","AirTime","ArrDelay","DepDelay","Distance","Origin","Dest"]]
df.head()
# Out:
#    Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  2008      1           3   2003.0        1955   2211.0        2225
# 1  2008      1           3    754.0         735   1002.0        1000
# 2  2008      1           3    628.0         620    804.0         750
# 3  2008      1           3   1829.0        1755   1959.0        1925
# 4  2008      1           3   1940.0        1915   2121.0        2110
#
#   UniqueCarrier  AirTime  ArrDelay  DepDelay  Distance Origin Dest
# 0            WN    116.0     -14.0       8.0       810    IAD  TPA
# 1            WN    113.0       2.0      19.0       810    IAD  TPA
# 2            WN     76.0      14.0       8.0       515    IND  BWI
# 3            WN     77.0      34.0      34.0       515    IND  BWI
# 4            WN     87.0      11.0      25.0       688    IND  JAX

# %%
df.describe()
# Out:
#             Year         Month    DayofMonth       DepTime    CRSDepTime  \
# count  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06  1.936758e+06
# mean      2008.0  6.111106e+00  1.575347e+01  1.518534e+03  1.467473e+03
# std          0.0  3.482546e+00  8.776272e+00  4.504853e+02  4.247668e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  1.203000e+03  1.135000e+03
# 50%       2008.0  6.000000e+00  1.600000e+01  1.545000e+03  1.510000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  1.900000e+03  1.815000e+03
# max       2008.0  1.200000e+01  3.100000e+01  2.400000e+03  2.359000e+03
#
#             ArrTime    CRSArrTime       AirTime      ArrDelay      DepDelay  \
# count  1.929648e+06  1.936758e+06  1.928371e+06  1.928371e+06  1.936758e+06
# mean   1.610141e+03  1.634225e+03  1.082771e+02  4.219988e+01  4.318518e+01
# std    5.481781e+02  4.646347e+02  6.864261e+01  5.678472e+01  5.340250e+01
# ...

# %%
fig, axes = plt.subplots(4, 2,figsize=(20,15))
axes = axes.flatten()
ax = sns.boxplot(x="DepTime", data=df, orient='h', ax=axes[0])
ax = sns.boxplot(x="CRSDepTime", data=df, orient='h', ax=axes[1])
ax = sns.boxplot(x="ArrTime", data=df, orient='h', ax=axes[2])
ax = sns.boxplot(x="CRSArrTime", data=df, orient='h', ax=axes[3])
ax = sns.boxplot(x="AirTime", data=df, orient='h', ax=axes[4])
ax = sns.boxplot(x="ArrDelay", data=df, orient='h', ax=axes[5])
ax = sns.boxplot(x="DepDelay", data=df, orient='h', ax=axes[6])
ax = sns.boxplot(x="Distance", data=df, orient='h', ax=axes[7])

# %% [markdown]
# ### *Velocidad media de vuelo*

# %%
df['AvgSpeed'] = round(df['Distance']/(df['AirTime']/60)) # velocidad media
df.head()
# Out:
#    Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  2008      1           3   2003.0        1955   2211.0        2225
# 1  2008      1           3    754.0         735   1002.0        1000
# 2  2008      1           3    628.0         620    804.0         750
# 3  2008      1           3   1829.0        1755   1959.0        1925
# 4  2008      1           3   1940.0        1915   2121.0        2110
#
#   UniqueCarrier  AirTime  ArrDelay  DepDelay  Distance Origin Dest  AvgSpeed
# 0            WN    116.0     -14.0       8.0       810    IAD  TPA     419.0
# 1            WN    113.0       2.0      19.0       810    IAD  TPA     430.0
# 2            WN     76.0      14.0       8.0       515    IND  BWI     407.0
# 3            WN     77.0      34.0      34.0       515    IND  BWI     401.0
# 4            WN     87.0      11.0      25.0       688    IND  JAX     474.0

# %%
df.groupby(by="UniqueCarrier")["AvgSpeed"].mean() # agrupo por aerolineas
# Out:
# UniqueCarrier
# 9E    369.287847
# AA    435.580509
# AQ    369.741935
# AS    418.436298
# B6    417.025508
# CO    432.761147
# DL    417.475494
# EV    370.877046
# F9    437.599773
# FL    409.993081
# HA    373.023019
# MQ    353.880891
# NW    402.795416
# OH    358.349055
# OO           inf
# UA    431.993229
# US    409.786383
# WN    396.553327
# XE           inf
# YV    347.974958
# Name: AvgSpeed, dtype: float64

# %%
plt.figure(figsize=(10,3))
sns.boxplot(data=df, x='UniqueCarrier',y='AvgSpeed')
# Out:
# <AxesSubplot:xlabel='UniqueCarrier', ylabel='AvgSpeed'>

# %% [markdown]
# ### *Si los vuelos han llegado tarde o no (True/False)*

# %%
df['ArrLate'] = df['ArrDelay']>0 # si ha llegado tarde o no
df.head()
# Out:
#    Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  2008      1           3   2003.0        1955   2211.0        2225
# 1  2008      1           3    754.0         735   1002.0        1000
# 2  2008      1           3    628.0         620    804.0         750
# 3  2008      1           3   1829.0        1755   1959.0        1925
# 4  2008      1           3   1940.0        1915   2121.0        2110
#
#   UniqueCarrier  AirTime  ArrDelay  DepDelay  Distance Origin Dest  AvgSpeed  \
# 0            WN    116.0     -14.0       8.0       810    IAD  TPA     419.0
# 1            WN    113.0       2.0      19.0       810    IAD  TPA     430.0
# 2            WN     76.0      14.0       8.0       515    IND  BWI     407.0
# 3            WN     77.0      34.0      34.0       515    IND  BWI     401.0
# 4            WN     87.0      11.0      25.0       688    IND  JAX     474.0
#
#    ArrLate
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True

# %%
df["ArrLate"].value_counts().plot.pie(autopct='%1.1f%%',shadow=True, startangle=90)
my_circle=plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

# %% [markdown]
# ### *Top 10 vuelos mas largos*

# %%
df2 = df[["UniqueCarrier","AirTime"]] # me quedo con las dos columnas que me interesan
df2 = df2.sort_values(by="AirTime", ascending=False) # ordeno los valores de forma descendente
df2 = df2.head(10) # me quedo con los diez primeros
df2
# Out:
#         UniqueCarrier  AirTime
# 1488690            HA   1091.0
# 1367047            HA    733.0
# 362529             CO    664.0
# 556381             CO    655.0
# 556385             CO    654.0
# 556379             CO    654.0
# 556377             CO    652.0
# 556386             CO    651.0
# 362852             CO    649.0
# 363750             CO    648.0

# %%
height = df2["AirTime"]
bars= df2["UniqueCarrier"]
y_pos = np.arange(len(bars))
plt.barh(y_pos, height)
plt.yticks(y_pos, bars)
plt.show()

# %% [markdown]
# ### *Top 10 vuelos mas retrasados*

# %%
df3 = df[["UniqueCarrier","ArrDelay"]] # me quedo con las dos columnas que me interesan
df3 = df3.sort_values(by="ArrDelay", ascending=False) # ordeno los valores de manera descendente
df3 = df3.head(10) # me quedo con los 10 primeros
df3
# Out:
#         UniqueCarrier  ArrDelay
# 322516             NW    2461.0
# 686014             NW    2453.0
# 839306             NW    1951.0
# 1009553            MQ    1707.0
# 1881639            NW    1655.0
# 1497823            NW    1583.0
# 685437             NW    1542.0
# 163379             AA    1525.0
# 1214839            NW    1510.0
# 521096             NW    1490.0

# %%
height = df3["ArrDelay"]
bars = df3["UniqueCarrier"]
x_pos = np.arange(len(bars))
plt.bar(x_pos, height, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(x_pos, bars)
plt.show()
