# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("DelayedFlights.csv")
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                 N         0           NaN           NaN      NaN
# 1                 N         0           NaN           NaN      NaN
# 2                 N         0           NaN           NaN      NaN
# 3                 N         0           2.0           0.0      0.0
# 4                 N         0           NaN           NaN      NaN
#
#   SecurityDelay  LateAircraftDelay
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3           0.0               32.0
# 4           NaN                NaN
#
# [5 rows x 30 columns]

# %%
df['AvgSpeed'] = round(df['Distance']/(df['AirTime']/60)) # velocidad media
df['ArrLate'] = df['ArrDelay']>0 # si ha llegado tarde o no
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  Cancelled CancellationCode  \
# 0   2211.0        2225            WN  ...          0                N
# 1   1002.0        1000            WN  ...          0                N
# 2    804.0         750            WN  ...          0                N
# 3   1959.0        1925            WN  ...          0                N
# 4   2121.0        2110            WN  ...          0                N
#
#    Diverted  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0         0           NaN           NaN       NaN            NaN
# 1         0           NaN           NaN       NaN            NaN
# 2         0           NaN           NaN       NaN            NaN
# 3         0           2.0           0.0       0.0            0.0
# 4         0           NaN           NaN       NaN            NaN
#
#   LateAircraftDelay AvgSpeed  ArrLate
# 0               NaN    419.0    False
# 1               NaN    430.0     True
# 2               NaN    407.0     True
# 3              32.0    401.0     True
# 4               NaN    474.0     True
#
# [5 rows x 32 columns]

# %%
df2 = df.groupby("UniqueCarrier").ArrLate.sum("True") # agrupo las aerolineas y sumo los retrasos totales
df2 = df2.sort_values(ascending=False) # ordeno de manera descendente
df2.head(10) # muestro las 10 aerolineas con mas retrasos
# Out:
# UniqueCarrier
# WN    324717
# AA    172197
# MQ    130647
# UA    123989
# OO    121942
# DL    100923
# XE     94313
# CO     83646
# US     83262
# EV     75170
# Name: ArrLate, dtype: int64

# %%
df3 = df["UniqueCarrier"].df["Airtime"]
df3 = df3.sort_values(ascending=False)
df3.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-13de8e362c0b> in <module>
# ----> 1 df3 = df["UniqueCarrier"].df["Airtime"]
#       2 df3 = df3.sort_values(ascending=False)
#       3 df3.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'df'
